# %%
import pandas as pd
import numpy as np

# %%
def get_db_url(db_name):
    from env import user, host, password
    return f'mysql+pymysql://{user}:{password}@{host}/{db_name}'

# %%
sql = """
    SELECT * from employees limit 3000
"""

# %%
# Called the "Connection string" b/c it has all the info to connect
url = get_db_url("employees")

df = pd.read_sql(sql, url)
df
# Out:
#       emp_no  birth_date first_name last_name gender   hire_date
# 0      10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1      10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2      10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3      10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4      10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12
# ...      ...         ...        ...       ...    ...         ...
# 2995   12996  1964-12-07     Khalil   Madeira      F  1992-07-14
# 2996   12997  1956-09-22       Zine     Swist      F  1991-03-22
# 2997   12998  1956-09-02     Nadjib   Rindone      M  1991-01-23
# 2998   12999  1963-10-13      Taizo    Koyama      F  1991-11-06
# 2999   13000  1955-01-31    Adhemar    Chiodo      F  1994-05-11
#
# [3000 rows x 6 columns]

# %%
pd.read_sql('SELECT * FROM employees LIMIT 5 OFFSET 50', url)
# Out:
#    emp_no  birth_date first_name  last_name gender   hire_date
# 0   10051  1953-07-28   Hidefumi      Caine      M  1992-10-15
# 1   10052  1961-02-26     Heping     Nitsch      M  1988-05-21
# 2   10053  1954-09-13     Sanjiv   Zschoche      F  1986-02-04
# 3   10054  1957-04-04     Mayumi  Schueller      M  1995-03-13
# 4   10055  1956-06-06     Georgy     Dredge      M  1992-04-27

# %% [markdown]
# 5 Once you have successfully run a query:
#
# a. Intentionally make a typo in the database url. What kind of error message do you see?
#
# b. Intentionally make an error in your SQL query. What does the error message look like?

# %%
###

# %%
###

# %% [markdown]
# 6. Read the employees and titles tables into two separate DataFrames.

# %%
employees = pd.read_sql('SELECT * FROM employees', url)
employees
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12
# ...        ...         ...        ...       ...    ...         ...
# 300019  499995  1958-09-24     Dekang  Lichtner      F  1993-01-12
# 300020  499996  1953-03-07       Zito      Baaz      M  1990-09-27
# 300021  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 300022  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 300023  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
# [300024 rows x 6 columns]

# %%
titles = pd.read_sql('SELECT * FROM titles', url)
titles
# Out:
#         emp_no            title   from_date     to_date
# 0        10001  Senior Engineer  1986-06-26  9999-01-01
# 1        10002            Staff  1996-08-03  9999-01-01
# 2        10003  Senior Engineer  1995-12-03  9999-01-01
# 3        10004         Engineer  1986-12-01  1995-12-01
# 4        10004  Senior Engineer  1995-12-01  9999-01-01
# ...        ...              ...         ...         ...
# 443303  499997         Engineer  1987-08-30  1992-08-29
# 443304  499997  Senior Engineer  1992-08-29  9999-01-01
# 443305  499998     Senior Staff  1998-12-27  9999-01-01
# 443306  499998            Staff  1993-12-27  1998-12-27
# 443307  499999         Engineer  1997-11-30  9999-01-01
#
# [443308 rows x 4 columns]

# %% [markdown]
# 7. How many rows and columns do you have in each DataFrame? Is that what you expected?

# %%
employees.shape
# Out:
# (300024, 6)

# %%
titles.shape
# Out:
# (443308, 4)

# %% [markdown]
# 8. Display the summary statistics for each DataFrame.¶

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300024 entries, 0 to 300023
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   emp_no      300024 non-null  int64
#  1   birth_date  300024 non-null  object
#  2   first_name  300024 non-null  object
#  3   last_name   300024 non-null  object
#  4   gender      300024 non-null  object
#  5   hire_date   300024 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 13.7+ MB

# %%
employees.describe()
# Out:
#               emp_no
# count  300024.000000
# mean   253321.763392
# std    161828.235540
# min     10001.000000
# 25%     85006.750000
# 50%    249987.500000
# 75%    424993.250000
# max    499999.000000

# %%
titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443308 entries, 0 to 443307
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   emp_no     443308 non-null  int64
#  1   title      443308 non-null  object
#  2   from_date  443308 non-null  object
#  3   to_date    443308 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 13.5+ MB

# %%
titles.describe()
# Out:
#               emp_no
# count  443308.000000
# mean   253075.034430
# std    161853.292613
# min     10001.000000
# 25%     84855.750000
# 50%    249847.500000
# 75%    424891.250000
# max    499999.000000

# %% [markdown]
# 9. How many unique titles are in the titles DataFrame?

# %%
titles.value_counts()
#sums all
#express the column title and value counts
# Out:
# emp_no  title             from_date   to_date
# 10001   Senior Engineer   1986-06-26  9999-01-01    1
# 299850  Engineer          1994-06-02  2001-06-02    1
# 299858  Senior Engineer   1988-06-16  1999-10-04    1
# 299857  Technique Leader  1991-10-12  9999-01-01    1
# 299856  Staff             1986-08-15  1992-08-14    1
#                                                    ..
# 109757  Staff             1994-05-07  1995-01-06    1
# 109756  Senior Engineer   1997-04-30  9999-01-01    1
#         Engineer          1991-05-01  1997-04-30    1
# 109755  Staff             1993-09-13  2000-09-13    1
# 499999  Engineer          1997-11-30  9999-01-01    1
# Length: 443308, dtype: int64

# %%
titles.title.value_counts()
# Out:
# Engineer              115003
# Staff                 107391
# Senior Engineer        97750
# Senior Staff           92853
# Technique Leader       15159
# Assistant Engineer     15128
# Manager                   24
# Name: title, dtype: int64

# %%
len(titles.title.value_counts())
# Out:
# 7

# %% [markdown]
# 10. What is the oldest date in the to_date column?

# %%
titles.to_date.sort_values().head(1)
# Out:
# 16064    1985-03-01
# Name: to_date, dtype: object

# %% [markdown]
# 11. What is the most recent date in the to_date column?

# %%
titles.to_date.sort_values().tail(1)
# Out:
# 443307    9999-01-01
# Name: to_date, dtype: object

# %%
#if we ignore #9999-01-01

#bool value to establish under condition of 9999 date
titles.to_date.astype(str) < '9999-01-01'
# Out:
# 0         False
# 1         False
# 2         False
# 3          True
# 4         False
#           ...
# 443303     True
# 443304    False
# 443305    False
# 443306     True
# 443307    False
# Name: to_date, Length: 443308, dtype: bool

# %%
#finish code
titles[(titles.to_date.astype(str) < '9999-01-01')].max()
# Out:
# emp_no                 499998
# title        Technique Leader
# from_date          2002-06-30
# to_date            2002-08-01
# dtype: object

# %% [markdown]
# # Exercises II

# %% [markdown]
# 1. Copy the users and roles DataFrames from the examples above.

# %%
users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'adam', 'jane', 'mike'],
    'role_id': [1, 2, 3, 3, np.nan, np.nan]
})
users
# Out:
#    id   name  role_id
# 0   1    bob      1.0
# 1   2    joe      2.0
# 2   3  sally      3.0
# 3   4   adam      3.0
# 4   5   jane      NaN
# 5   6   mike      NaN

# %%
roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter']
})
roles
# Out:
#    id       name
# 0   1      admin
# 1   2     author
# 2   3   reviewer
# 3   4  commenter

# %% [markdown]
# 2. What is the result of using a right join on the DataFrames?

# %%
users_roles = pd.concat([users, roles], axis=0)
users_roles
# Out:
#    id       name  role_id
# 0   1        bob      1.0
# 1   2        joe      2.0
# 2   3      sally      3.0
# 3   4       adam      3.0
# 4   5       jane      NaN
# 5   6       mike      NaN
# 0   1      admin      NaN
# 1   2     author      NaN
# 2   3   reviewer      NaN
# 3   4  commenter      NaN

# %%
users.merge(roles, left_on='role_id', right_on='id', how='right')
# Out:
#    id_x name_x  role_id  id_y     name_y
# 0   1.0    bob      1.0     1      admin
# 1   2.0    joe      2.0     2     author
# 2   3.0  sally      3.0     3   reviewer
# 3   4.0   adam      3.0     3   reviewer
# 4   NaN    NaN      NaN     4  commenter

# %% [markdown]
# 3. What is the result of using an outer join on the DataFrames?

# %%
users.merge(roles, left_on='role_id', right_on='id', how='outer', indicator=True)
# Out:
#    id_x name_x  role_id  id_y     name_y      _merge
# 0   1.0    bob      1.0   1.0      admin        both
# 1   2.0    joe      2.0   2.0     author        both
# 2   3.0  sally      3.0   3.0   reviewer        both
# 3   4.0   adam      3.0   3.0   reviewer        both
# 4   5.0   jane      NaN   NaN        NaN   left_only
# 5   6.0   mike      NaN   NaN        NaN   left_only
# 6   NaN    NaN      NaN   4.0  commenter  right_only

# %% [markdown]
# 4. What happens if you drop the foreign keys from the DataFrames and try to merge them?

# %%
df.drop(columns='column_name')

df.drop(columns=["col1","col2"])

#to drop columns with associated column code 

###If we don't have foreign keys we don't have anything to match###
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-3357e6c51927> in <module>
# ----> 1 df.drop(columns='column_name')
#       2
#       3 df.drop(columns=["col1","col2"])
#       4
#       5 #to drop columns with associated column code
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# ...

# %%
#if you drop your keys you can't merge them

# %% [markdown]
# 5. Load the mpg dataset from PyDataset.

# %%
import pydataset
from pydataset import data

mpg = data('mpg')
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %%
#added this piece
pydataset.data('mpg', show_doc=True)
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %%
mpg_raw = mpg

# %% [markdown]
# 6. Output and read the documentation for the mpg dataset.

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %% [markdown]
# 7. How many rows and columns are in the dataset?

# %%
mpg.shape
# Out:
# (234, 11)

# %% [markdown]
# 8. Check out your column names and perform any cleanup you may want on them.

# %%
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
mpg = mpg.rename(columns = {'hwy' : 'highway'})
mpg = mpg.rename(columns = {'cty' : 'city'})

# %%
print(mpg.columns)
# Out:
# Index(['manufacturer', 'model', 'displ', 'year', 'cyl', 'trans', 'drv', 'cty',
#        'hwy', 'fl', 'class'],
#       dtype='object')

# %% [markdown]
# 9. Display the summary statistics for the dataset.

# %%
mpg.describe()
# Out:
#             displ         year         cyl        city     highway
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   city          234 non-null    int64
#  8   highway       234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %% [markdown]
# 10. How many different manufacturers are there?

# %%
#how many manufactures and how many they produce in the dataset
mpg.manufacturer.value_counts()
# Out:
# dodge         37
# toyota        34
# volkswagen    27
# ford          25
# chevrolet     19
# audi          18
# subaru        14
# hyundai       14
# nissan        13
# honda          9
# jeep           8
# pontiac        5
# land rover     4
# mercury        4
# lincoln        3
# Name: manufacturer, dtype: int64

# %%
#the count of manufacturers

len(mpg['manufacturer'].unique())
# Out:
# 15

# %% [markdown]
# 11. How many different models are there?

# %%
#the counts of every model
mpg.model.value_counts()
# Out:
# caravan 2wd               11
# ram 1500 pickup 4wd       10
# civic                      9
# dakota pickup 4wd          9
# mustang                    9
# jetta                      9
# impreza awd                8
# a4 quattro                 8
# grand cherokee 4wd         8
# a4                         7
# camry solara               7
# sonata                     7
# passat                     7
# camry                      7
# toyota tacoma 4wd          7
# f150 pickup 4wd            7
# tiburon                    7
# durango 4wd                7
# explorer 4wd               6
# altima                     6
# 4runner 4wd                6
# new beetle                 6
# forester awd               6
# c1500 suburban 2wd         5
# grand prix                 5
# gti                        5
# malibu                     5
# corolla                    5
# corvette                   5
# pathfinder 4wd             4
# range rover                4
# mountaineer 4wd            4
# ...

# %%
#the amount of unique models there are
len(mpg['model'].unique())
# Out:
# 38

# %%
#using a 'groupby' via Ryan

mpg.groupby("model").model.count()
# Out:
# model
# 4runner 4wd                6
# a4                         7
# a4 quattro                 8
# a6 quattro                 3
# altima                     6
# c1500 suburban 2wd         5
# camry                      7
# camry solara               7
# caravan 2wd               11
# civic                      9
# corolla                    5
# corvette                   5
# dakota pickup 4wd          9
# durango 4wd                7
# expedition 2wd             3
# explorer 4wd               6
# f150 pickup 4wd            7
# forester awd               6
# grand cherokee 4wd         8
# grand prix                 5
# gti                        5
# impreza awd                8
# jetta                      9
# k1500 tahoe 4wd            4
# land cruiser wagon 4wd     2
# malibu                     5
# maxima                     3
# mountaineer 4wd            4
# mustang                    9
# navigator 2wd              3
# new beetle                 6
# passat                     7
# ...

# %% [markdown]
# 12. Create a column named mileage_difference like you did in the DataFrames exercises; this column should contain the difference between highway and city mileage for each car.

# %%
mpg['mileage_difference'] = (mpg.highway - mpg.city)

# %% [markdown]
# 13. Create a column named average_mileage like you did in the DataFrames exercises; this is the mean of the city and highway mileage.

# %%
mpg['average_mileage'] = ((mpg.highway + mpg.city)/2)
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
# ...

# %%
#Mason's code:
#mpg['average_mileage'] = mpg[['city', 'hwy']].mean(axis = 1)

# %% [markdown]
# 14. Create a new column on the mpg dataset named is_automatic that holds boolean values denoting whether the car has an automatic transmission.

# %%
mpg['is_automatic'] = mpg.trans.str.contains("auto")
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
# ...

# %%
#Jon's Code - #using .apply 
mpg[is_automatic] = mpg.trans.apply(lambda value: value[0] == 'a')

#another method provided:
mpg['is_automatic'] = mpg.trans.str.startswith('a')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-2402a67c1019> in <module>
#       1 #Jon's Code - #using .apply
# ----> 2 mpg[is_automatic] = mpg.trans.apply(lambda value: value[0] == 'a')
#       3
#       4 #another method provided:
#       5 mpg['is_automatic'] = mpg.trans.str.startswith('a')
#
# NameError: name 'is_automatic' is not defined

# %% [markdown]
# 15. Using the mpg dataset, find out which which manufacturer has the best miles per gallon on average?

# %%
mpg.groupby('manufacturer').average_mileage.mean().sort_values().tail(1)
# Out:
# manufacturer
# honda    28.5
# Name: average_mileage, dtype: float64

# %% [markdown]
# 16. Do automatic or manual cars have better miles per gallon?

# %%
mpg.groupby('is_automatic').average_mileage.mean()
# Out:
# is_automatic
# False    22.227273
# True     19.130573
# Name: average_mileage, dtype: float64

# %%
#False = Manual
#True = Automatic

#Thus manuals have better mpg than automatics

# %% [markdown]
# # Exercises III

# %% [markdown]
# 1. Use your get_db_url function to help you explore the data from the chipotle database.

# %%
def get_db_url(db_name):
    from env import user, host, password
    return f'mysql+pymysql://{user}:{password}@{host}/{db_name}'

# %%
sql = """
    SELECT * from orders
"""

# %%
url = get_db_url("chipotle")

chipotle_df = pd.read_sql(sql, url)
chipotle_df
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# ...

# %%
raw_chipotle_df = chipotle_df

# %%
chipotle_df.head()
# Out:
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
#
#                                                            choice_description  \
# 0                                                                         nan
# 1                                                                [Clementine]
# 2                                                                     [Apple]
# 3                                                                         nan
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
#
#   item_price
# 0     $2.39
# 1     $3.39
# 2     $3.39
# 3     $2.39
# 4    $16.98

# %% [markdown]
# 2. What is the total price for each order?

# %%
#need to clean data and put into float so I can sum order values

chipotle_df.item_price = chipotle_df.item_price.str.replace('$','').str.replace(',','').astype(float)
chipotle_df.item_price
# Out:
# <ipython-input-60-6fa99054c160>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   chipotle_df.item_price = chipotle_df.item_price.str.replace('$','').str.replace(',','').astype(float)
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: float64

# %%
#jon used lambda function:
# chipotle_df['item_price'] = chipotle_df.item_price.apply(lambda value: float(value[1:].strip()))

# %%
chipotle_df.groupby("order_id").item_price.agg('sum')
# Out:
# order_id
# 1       11.56
# 2       16.98
# 3       12.67
# 4       21.00
# 5       13.70
#         ...
# 1830    23.00
# 1831    12.90
# 1832    13.20
# 1833    23.50
# 1834    28.75
# Name: item_price, Length: 1834, dtype: float64

# %%
chipotle_df.groupby('order_id').item_price.sum()
# Out:
# order_id
# 1       11.56
# 2       16.98
# 3       12.67
# 4       21.00
# 5       13.70
#         ...
# 1830    23.00
# 1831    12.90
# 1832    13.20
# 1833    23.50
# 1834    28.75
# Name: item_price, Length: 1834, dtype: float64

# %% [markdown]
# 3. What are the most popular 3 items?

# %%
chipotle_df.groupby('item_name').quantity.agg('count')
# Out:
# item_name
# 6 Pack Soft Drink                         54
# Barbacoa Bowl                             66
# Barbacoa Burrito                          91
# Barbacoa Crispy Tacos                     11
# Barbacoa Salad Bowl                       10
# Barbacoa Soft Tacos                       25
# Bottled Water                            162
# Bowl                                       2
# Burrito                                    6
# Canned Soda                              104
# Canned Soft Drink                        301
# Carnitas Bowl                             68
# Carnitas Burrito                          59
# Carnitas Crispy Tacos                      7
# Carnitas Salad                             1
# Carnitas Salad Bowl                        6
# Carnitas Soft Tacos                       40
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chicken Crispy Tacos                      47
# Chicken Salad                              9
# ...

# %%
chipotle_df.groupby('item_name').quantity.agg(sum).sort_values(ascending = False).head(3)
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Name: quantity, dtype: int64

# %% [markdown]
# 4. Which item has produced the most revenue?

# %%
chipotle_df.groupby('item_name').item_price.agg('sum').sort_values(ascending = False).head(1)
# Out:
# item_name
# Chicken Bowl    7342.73
# Name: item_price, dtype: float64

# %% [markdown]
# 5. Join the employees and titles DataFrames together.

# %%
#employees and titles data frames from employees
# .merge
# Perform an outer join specifying the left and right DataFrame keys.
#users.merge(roles, left_on='role_id', right_on='id', how='outer', indicator=True

#they share emp_id

employees_titles = employees.merge(titles, left_on='emp_no', right_on='emp_no', how='inner', indicator = True)
employees_titles
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date  \
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# ...        ...         ...        ...       ...    ...         ...
# 443303  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443304  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443305  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443306  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443307  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
#                   title   from_date     to_date _merge
# 0       Senior Engineer  1986-06-26  9999-01-01   both
# ...

# %% [markdown]
# 6. For each title, find the hire date of the employee that was hired most recently with that title.

# %%
employees_titles.groupby('title').hire_date.agg('max')
# Out:
# title
# Assistant Engineer    1999-12-24
# Engineer              2000-01-28
# Manager               1992-02-05
# Senior Engineer       2000-01-01
# Senior Staff          2000-01-13
# Staff                 2000-01-12
# Technique Leader      1999-12-31
# Name: hire_date, dtype: object

# %% [markdown]
# 7. Write the code necessary to create a cross tabulation of the number of titles by department. (Hint: this will involve a combination of SQL code to pull the necessary data and python/pandas code to perform the manipulations.)

# %%
# I need departments query

sql = """
    SELECT * from departments limit 3000
"""

url = get_db_url("employees")

departments = pd.read_sql(sql, url)
departments
# Out:
#   dept_no           dept_name
# 0    d009    Customer Service
# 1    d005         Development
# 2    d002             Finance
# 3    d003     Human Resources
# 4    d001           Marketing
# 5    d004          Production
# 6    d006  Quality Management
# 7    d008            Research
# 8    d007               Sales

# %%
sql = """
    SELECT * from titles
"""

url = get_db_url("employees")

titles = pd.read_sql(sql, url)
titles
# Out:
#         emp_no            title   from_date     to_date
# 0        10001  Senior Engineer  1986-06-26  9999-01-01
# 1        10002            Staff  1996-08-03  9999-01-01
# 2        10003  Senior Engineer  1995-12-03  9999-01-01
# 3        10004         Engineer  1986-12-01  1995-12-01
# 4        10004  Senior Engineer  1995-12-01  9999-01-01
# ...        ...              ...         ...         ...
# 443303  499997         Engineer  1987-08-30  1992-08-29
# 443304  499997  Senior Engineer  1992-08-29  9999-01-01
# 443305  499998     Senior Staff  1998-12-27  9999-01-01
# 443306  499998            Staff  1993-12-27  1998-12-27
# 443307  499999         Engineer  1997-11-30  9999-01-01
#
# [443308 rows x 4 columns]

# %%
#join departments and titles
#employees_titles = employees.merge(titles, left_on='emp_no', right_on='emp_no', how='inner', indicator = True)


#look at your sql code to bring in title and department

# %%
#My Code (was incorrect)

# sql = """
#     SELECT emp_no, dept_no, title, dept_name
# FROM dept_emp
# JOIN titles USING (emp_no)
# JOIN departments USING (dept_no);

# """
# url = get_db_url("employees")


# department_titles = pd.read_sql(sql, url)
# department_titles

# %%
sql = """
SELECT emp_no, title, dept_name

FROM employees
JOIN titles USING(emp_no)
JOIN dept_emp USING(emp_no)
JOIN departments USING(dept_no)

where titles.to_date = "9999-01-01"
"""
url = get_db_url("employees")


department_titles = pd.read_sql(sql, url)
department_titles
# Out:
#         emp_no            title        dept_name
# 0        10001  Senior Engineer      Development
# 1        10002            Staff            Sales
# 2        10003  Senior Engineer       Production
# 3        10004  Senior Engineer       Production
# 4        10005     Senior Staff  Human Resources
# ...        ...              ...              ...
# 265327  499995         Engineer       Production
# 265328  499996  Senior Engineer       Production
# 265329  499997  Senior Engineer      Development
# 265330  499998     Senior Staff          Finance
# 265331  499999         Engineer       Production
#
# [265332 rows x 3 columns]

# %%
#you have your columns necessary - now express pythonic code to group the titles

# number of titles by department

# %%
department_titles.groupby('title').emp_no.agg('count')
# Out:
# title
# Assistant Engineer     3953
# Engineer              34203
# Manager                   9
# Senior Engineer       94950
# Senior Staff          90672
# Staff                 28234
# Technique Leader      13311
# Name: emp_no, dtype: int64

# %%
department_titles.groupby('dept_name').emp_no.agg('count')
# Out:
# dept_name
# Customer Service      18978
# Development           68392
# Finance               13850
# Human Resources       14260
# Marketing             16252
# Production            58706
# Quality Management    15990
# Research              16904
# Sales                 42000
# Name: emp_no, dtype: int64

# %%
#From Jon:
#Get crosstab of title and dept_name column
pd.crosstab(department_titles.title, department_titles.dept_name)
# Out:
# dept_name           Customer Service  Development  Finance  Human Resources  \
# title
# Assistant Engineer                68         1833        0                0
# Engineer                         627        15677        0                0
# Manager                            1            1        1                1
# Senior Engineer                 1790        43364        0                0
# Senior Staff                   12349         1085    10650            10843
# Staff                           3902          315     3199             3416
# Technique Leader                 241         6117        0                0
#
# dept_name           Marketing  Production  Quality Management  Research  Sales
# title
# Assistant Engineer          0        1542                 433        77      0
# Engineer                    0       13325                3744       830      0
# Manager                     1           1                   1         1      1
# ...
